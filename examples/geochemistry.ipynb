# %% [markdown]
# # Synthetic Geochemistry Data Generation
#
# To generate synthetic data from GMM, the user may choose the model parameters from real world datasets.
#
# In this notebook, the dataset **Geochemical Variations in Igneous Rocks – Mining** (https://www.kaggle.com/datasets/cristianminas/geochemical-variations-in-igneous-rocks-mining) contains 10 variables (weights in % of some major oxides) and the corresponding rock classification.
#
# We analyze statistics of some rock types and generate synthetic data considering these parameters.
#
# ---
#
# ## 📌 1. Carregar bibliotecas necessárias
#
# ```python
# import pandas as pd
# import numpy as np
#
# # visualização
# import matplotlib.pyplot as plt
#
# # seu gerador sintético
# from ..main import SyntheticGMMGenerator
# from ..visualization import ScatterPlotVisualizer

# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath(".."))
from main import SyntheticGMMGenerator
from visualization import ScatterPlotVisualizer

# %%
df1 = pd.read_csv("Data1.csv")
print(df1.shape)
# df1.describe()
df1["rock_name"].value_counts()
# Out:
# (4213, 13)
# rock_name
# Basaltic andesite          1181
# Andesite                    878
# Basalt                      595
# Dacite                      215
# Granite                     145
#                            ...
# Andesite  sill                1
# Basaltic andesite  sill       1
# Diorite intrusion             1
# Dacite stock                  1
# Dacite  tuff                  1
# Name: count, Length: 97, dtype: int64

# %%
df2 = pd.read_csv("multiclass_clean.csv")
print(df2.shape)
# df2.describe()
df2["ROCK1"].value_counts()
# Out:
# (2191, 11)
# ROCK1
# BASALT       824
# KOMATIITE    415
# RHYOLITE     339
# ANDESITE     235
# THOLEIITE    162
# GABBRO       109
# DACITE       107
# Name: count, dtype: int64
