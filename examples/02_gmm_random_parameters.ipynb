# %% [markdown]
# # Synthetic Data Generation with GMM — Random Parameter Initialization
#
# This notebook demonstrates how to generate synthetic data using a Gaussian Mixture Model (GMM) with randomly initialized parameters.
#
# Instead of manually specifying the model parameters, we use:
#
# ```python
# generator.set_random_params(cov_type="full")
